# %%
import numpy as np

a = np.random.randint(1, 10, size=(3,4,2))

print(a)
# Out:
# [[[5 6]
#   [5 3]
#   [3 1]
#   [7 3]]
#
#  [[3 6]
#   [6 1]
#   [5 4]
#   [4 2]]
#
#  [[6 6]
#   [1 6]
#   [7 8]
#   [1 7]]]

# %%
a=np.array([6,7,8,9,10])
a[2]
# Out:
# np.int64(8)

# %%
a[[2,3]]
# Out:
# array([8, 9])

# %%
,[5,7,8,9,11]]])

# %%
a[0]
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
a[0,0,1]
# Out:
# np.int64(7)

# %%
a=np.array([6,7,8,9,10])
a[0:3]
# Out:
# array([6, 7, 8])

# %%
a[[0,1,2]]
# Out:
# array([6, 7, 8])

# %%
a[[1,2,0]]
# Out:
# array([7, 8, 6])

# %%
a>8
# Out:
# array([False, False, False,  True,  True])

# %%
a
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
a[[True,True,True,False,True]]
# Out:
# array([ 6,  7,  8, 10])

# %%
a[a>8]
# Out:
# array([ 9, 10])

# %%
import numpy as np

a = np.array([1,2,3,4,5])

np.save("myarray.npy", a)

# %%
b = np.load("myarray.npy")

print(b)
# Out:
# [1 2 3 4 5]

# %%
import json 
# Create dictionary
data = {
    "name": "Malavika",
    "age": 20,
    "course": "Mathematics"
}

# %%
with open("demo.json","w") as j:
    json.dump(data,j)

# %%
with open("demo.json","r") as j:
    a=json.load(j)

# %%
a
# Out:
# {'name': 'Malavika', 'age': 20, 'course': 'Mathematics'}

# %%
import pickle

# %%
data=100

# %%
with open("demo.pkl","wb") as j:
    pickle.dump(data,j)

# %%
with open("demo.pkl","rb") as j:
    a=pickle.load(j)

# %%
a
# Out:
# 100

# %%
a=np.array([5,6,7,8])

# %%
a.max()
# Out:
# np.int64(8)
